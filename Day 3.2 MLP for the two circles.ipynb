# %%
from sklearn.datasets import make_circles
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
from matplotlib import pyplot
import matplotlib.pyplot as plt

# %% [markdown]
# # Generate 2D dataset

# %%
x,y=make_circles(n_samples=1000, noise=0.1,random_state=1)
plt.scatter(x[:,0],x[:,1],c=y,s=50,cmap='autumn')

# %% [markdown]
# # Split the train & test

# %%
n_train=500
trainX,testX=x[:n_train,:],x[n_train:,:]
trainy,testy=y[:n_train],y[n_train:]

# %% [markdown]
# # Define the model

# %%
model=Sequential()
model.add(Dense(50,input_dim=2,activation='relu',kernel_initializer='he_uniform'))
model.add(Dense(1,activation='sigmoid'))

# Optimizer
optm=SGD(learning_rate=0.01, momentum=0.9)

# compiler

model.compile(loss='binary_crossentropy',optimizer=optm,metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 1, 16)             96
#
#  dense_8 (Dense)             (None, 1, 32)             544
#
#  batch_normalization_1 (Bat  (None, 1, 32)             4
#  chNormalization)
#
#  dense_9 (Dense)             (None, 1, 2)              66
#
# =================================================================
# Total params: 710 (2.77 KB)
# Trainable params: 708 (2.77 KB)
# Non-trainable params: 2 (8.00 Byte)
# _________________________________________________________________

# %%
# Run the NN

history=model.fit(trainX,trainy,validation_data=(testX,testy),epochs=100,verbose=2)
# Out:
# Epoch 1/100
# 16/16 - 1s - loss: 0.7018 - accuracy: 0.4960 - val_loss: 0.6956 - val_accuracy: 0.5020 - 1s/epoch - 78ms/step
# Epoch 2/100
# 16/16 - 0s - loss: 0.6877 - accuracy: 0.5540 - val_loss: 0.6913 - val_accuracy: 0.5120 - 67ms/epoch - 4ms/step
# Epoch 3/100
# 16/16 - 0s - loss: 0.6765 - accuracy: 0.5520 - val_loss: 0.6824 - val_accuracy: 0.5420 - 68ms/epoch - 4ms/step
# Epoch 4/100
# 16/16 - 0s - loss: 0.6724 - accuracy: 0.5460 - val_loss: 0.6758 - val_accuracy: 0.5140 - 70ms/epoch - 4ms/step
# Epoch 5/100
# 16/16 - 0s - loss: 0.6685 - accuracy: 0.5720 - val_loss: 0.6792 - val_accuracy: 0.6100 - 75ms/epoch - 5ms/step
# Epoch 6/100
# 16/16 - 0s - loss: 0.6644 - accuracy: 0.5980 - val_loss: 0.6708 - val_accuracy: 0.5240 - 67ms/epoch - 4ms/step
# Epoch 7/100
# 16/16 - 0s - loss: 0.6616 - accuracy: 0.6140 - val_loss: 0.6662 - val_accuracy: 0.6220 - 67ms/epoch - 4ms/step
# Epoch 8/100
# 16/16 - 0s - loss: 0.6576 - accuracy: 0.5660 - val_loss: 0.6618 - val_accuracy: 0.5480 - 80ms/epoch - 5ms/step
# Epoch 9/100
# 16/16 - 0s - loss: 0.6496 - accuracy: 0.6180 - val_loss: 0.6536 - val_accuracy: 0.5940 - 69ms/epoch - 4ms/step
# Epoch 10/100
# 16/16 - 0s - loss: 0.6455 - accuracy: 0.6420 - val_loss: 0.6538 - val_accuracy: 0.6120 - 70ms/epoch - 4ms/step
# Epoch 11/100
# 16/16 - 0s - loss: 0.6416 - accuracy: 0.6060 - val_loss: 0.6460 - val_accuracy: 0.6480 - 79ms/epoch - 5ms/step
# Epoch 12/100
# 16/16 - 0s - loss: 0.6380 - accuracy: 0.7460 - val_loss: 0.6392 - val_accuracy: 0.6360 - 70ms/epoch - 4ms/step
# Epoch 13/100
# 16/16 - 0s - loss: 0.6320 - accuracy: 0.7100 - val_loss: 0.6410 - val_accuracy: 0.6380 - 74ms/epoch - 5ms/step
# Epoch 14/100
# 16/16 - 0s - loss: 0.6266 - accuracy: 0.6480 - val_loss: 0.6323 - val_accuracy: 0.6380 - 81ms/epoch - 5ms/step
# Epoch 15/100
# 16/16 - 0s - loss: 0.6233 - accuracy: 0.7280 - val_loss: 0.6266 - val_accuracy: 0.7300 - 83ms/epoch - 5ms/step
# Epoch 16/100
# 16/16 - 0s - loss: 0.6174 - accuracy: 0.7060 - val_loss: 0.6264 - val_accuracy: 0.6140 - 74ms/epoch - 5ms/step
# Epoch 17/100
# 16/16 - 0s - loss: 0.6162 - accuracy: 0.6720 - val_loss: 0.6199 - val_accuracy: 0.7020 - 69ms/epoch - 4ms/step
# Epoch 18/100
# 16/16 - 0s - loss: 0.6118 - accuracy: 0.7180 - val_loss: 0.6193 - val_accuracy: 0.6660 - 61ms/epoch - 4ms/step
# Epoch 19/100
# 16/16 - 0s - loss: 0.6063 - accuracy: 0.7280 - val_loss: 0.6080 - val_accuracy: 0.7140 - 74ms/epoch - 5ms/step
# Epoch 20/100
# 16/16 - 0s - loss: 0.6000 - accuracy: 0.7580 - val_loss: 0.6078 - val_accuracy: 0.7360 - 67ms/epoch - 4ms/step
# Epoch 21/100
# 16/16 - 0s - loss: 0.6005 - accuracy: 0.7300 - val_loss: 0.6018 - val_accuracy: 0.7100 - 70ms/epoch - 4ms/step
# Epoch 22/100
# 16/16 - 0s - loss: 0.5976 - accuracy: 0.7440 - val_loss: 0.5933 - val_accuracy: 0.7660 - 67ms/epoch - 4ms/step
# Epoch 23/100
# 16/16 - 0s - loss: 0.5865 - accuracy: 0.7580 - val_loss: 0.5987 - val_accuracy: 0.7560 - 70ms/epoch - 4ms/step
# Epoch 24/100
# 16/16 - 0s - loss: 0.5866 - accuracy: 0.7500 - val_loss: 0.5868 - val_accuracy: 0.7560 - 81ms/epoch - 5ms/step
# Epoch 25/100
# 16/16 - 0s - loss: 0.5810 - accuracy: 0.7800 - val_loss: 0.5832 - val_accuracy: 0.7740 - 69ms/epoch - 4ms/step
# Epoch 26/100
# 16/16 - 0s - loss: 0.5746 - accuracy: 0.7580 - val_loss: 0.5817 - val_accuracy: 0.7400 - 78ms/epoch - 5ms/step
# Epoch 27/100
# 16/16 - 0s - loss: 0.5718 - accuracy: 0.7740 - val_loss: 0.5755 - val_accuracy: 0.7820 - 70ms/epoch - 4ms/step
# Epoch 28/100
# 16/16 - 0s - loss: 0.5663 - accuracy: 0.7680 - val_loss: 0.5683 - val_accuracy: 0.7800 - 70ms/epoch - 4ms/step
# Epoch 29/100
# 16/16 - 0s - loss: 0.5655 - accuracy: 0.7760 - val_loss: 0.5716 - val_accuracy: 0.7820 - 80ms/epoch - 5ms/step
# Epoch 30/100
# 16/16 - 0s - loss: 0.5576 - accuracy: 0.7800 - val_loss: 0.5594 - val_accuracy: 0.7840 - 80ms/epoch - 5ms/step
# Epoch 31/100
# 16/16 - 0s - loss: 0.5543 - accuracy: 0.8040 - val_loss: 0.5601 - val_accuracy: 0.8000 - 80ms/epoch - 5ms/step
# Epoch 32/100
# 16/16 - 0s - loss: 0.5500 - accuracy: 0.7940 - val_loss: 0.5540 - val_accuracy: 0.7780 - 70ms/epoch - 4ms/step
# Epoch 33/100
# 16/16 - 0s - loss: 0.5460 - accuracy: 0.7880 - val_loss: 0.5490 - val_accuracy: 0.7980 - 90ms/epoch - 6ms/step
# Epoch 34/100
# 16/16 - 0s - loss: 0.5414 - accuracy: 0.7960 - val_loss: 0.5458 - val_accuracy: 0.7820 - 80ms/epoch - 5ms/step
# Epoch 35/100
# 16/16 - 0s - loss: 0.5374 - accuracy: 0.7940 - val_loss: 0.5411 - val_accuracy: 0.8020 - 80ms/epoch - 5ms/step
# Epoch 36/100
# 16/16 - 0s - loss: 0.5345 - accuracy: 0.8120 - val_loss: 0.5369 - val_accuracy: 0.8000 - 70ms/epoch - 4ms/step
# Epoch 37/100
# 16/16 - 0s - loss: 0.5340 - accuracy: 0.7760 - val_loss: 0.5321 - val_accuracy: 0.7940 - 80ms/epoch - 5ms/step
# Epoch 38/100
# 16/16 - 0s - loss: 0.5273 - accuracy: 0.8040 - val_loss: 0.5289 - val_accuracy: 0.8020 - 80ms/epoch - 5ms/step
# Epoch 39/100
# 16/16 - 0s - loss: 0.5225 - accuracy: 0.7960 - val_loss: 0.5250 - val_accuracy: 0.8000 - 67ms/epoch - 4ms/step
# Epoch 40/100
# 16/16 - 0s - loss: 0.5167 - accuracy: 0.8200 - val_loss: 0.5190 - val_accuracy: 0.8160 - 75ms/epoch - 5ms/step
# Epoch 41/100
# 16/16 - 0s - loss: 0.5128 - accuracy: 0.8220 - val_loss: 0.5168 - val_accuracy: 0.8140 - 63ms/epoch - 4ms/step
# Epoch 42/100
# 16/16 - 0s - loss: 0.5108 - accuracy: 0.8240 - val_loss: 0.5118 - val_accuracy: 0.8140 - 70ms/epoch - 4ms/step
# Epoch 43/100
# 16/16 - 0s - loss: 0.5057 - accuracy: 0.8200 - val_loss: 0.5095 - val_accuracy: 0.8000 - 70ms/epoch - 4ms/step
# Epoch 44/100
# 16/16 - 0s - loss: 0.5030 - accuracy: 0.8220 - val_loss: 0.5030 - val_accuracy: 0.8260 - 70ms/epoch - 4ms/step
# Epoch 45/100
# 16/16 - 0s - loss: 0.4978 - accuracy: 0.8240 - val_loss: 0.4989 - val_accuracy: 0.8160 - 69ms/epoch - 4ms/step
# Epoch 46/100
# 16/16 - 0s - loss: 0.4943 - accuracy: 0.8200 - val_loss: 0.4949 - val_accuracy: 0.8240 - 69ms/epoch - 4ms/step
# Epoch 47/100
# 16/16 - 0s - loss: 0.4927 - accuracy: 0.8120 - val_loss: 0.4907 - val_accuracy: 0.8100 - 75ms/epoch - 5ms/step
# Epoch 48/100
# 16/16 - 0s - loss: 0.4892 - accuracy: 0.8180 - val_loss: 0.4874 - val_accuracy: 0.8180 - 75ms/epoch - 5ms/step
# Epoch 49/100
# 16/16 - 0s - loss: 0.4879 - accuracy: 0.8100 - val_loss: 0.4814 - val_accuracy: 0.8120 - 80ms/epoch - 5ms/step
# Epoch 50/100
# 16/16 - 0s - loss: 0.4816 - accuracy: 0.8240 - val_loss: 0.4801 - val_accuracy: 0.8360 - 60ms/epoch - 4ms/step
# Epoch 51/100
# 16/16 - 0s - loss: 0.4772 - accuracy: 0.8220 - val_loss: 0.4755 - val_accuracy: 0.8340 - 70ms/epoch - 4ms/step
# Epoch 52/100
# 16/16 - 0s - loss: 0.4744 - accuracy: 0.8100 - val_loss: 0.4711 - val_accuracy: 0.8220 - 60ms/epoch - 4ms/step
# Epoch 53/100
# 16/16 - 0s - loss: 0.4723 - accuracy: 0.8180 - val_loss: 0.4706 - val_accuracy: 0.8240 - 70ms/epoch - 4ms/step
# Epoch 54/100
# 16/16 - 0s - loss: 0.4674 - accuracy: 0.8260 - val_loss: 0.4629 - val_accuracy: 0.8300 - 70ms/epoch - 4ms/step
# Epoch 55/100
# 16/16 - 0s - loss: 0.4653 - accuracy: 0.8240 - val_loss: 0.4606 - val_accuracy: 0.8240 - 73ms/epoch - 5ms/step
# Epoch 56/100
# 16/16 - 0s - loss: 0.4622 - accuracy: 0.8220 - val_loss: 0.4576 - val_accuracy: 0.8360 - 66ms/epoch - 4ms/step
# Epoch 57/100
# 16/16 - 0s - loss: 0.4579 - accuracy: 0.8200 - val_loss: 0.4540 - val_accuracy: 0.8220 - 68ms/epoch - 4ms/step
# Epoch 58/100
# 16/16 - 0s - loss: 0.4538 - accuracy: 0.8300 - val_loss: 0.4513 - val_accuracy: 0.8380 - 90ms/epoch - 6ms/step
# Epoch 59/100
# 16/16 - 0s - loss: 0.4532 - accuracy: 0.8260 - val_loss: 0.4475 - val_accuracy: 0.8280 - 83ms/epoch - 5ms/step
# Epoch 60/100
# 16/16 - 0s - loss: 0.4507 - accuracy: 0.8220 - val_loss: 0.4490 - val_accuracy: 0.8360 - 60ms/epoch - 4ms/step
# Epoch 61/100
# 16/16 - 0s - loss: 0.4469 - accuracy: 0.8240 - val_loss: 0.4412 - val_accuracy: 0.8360 - 60ms/epoch - 4ms/step
# Epoch 62/100
# 16/16 - 0s - loss: 0.4469 - accuracy: 0.8200 - val_loss: 0.4408 - val_accuracy: 0.8420 - 70ms/epoch - 4ms/step
# Epoch 63/100
# 16/16 - 0s - loss: 0.4466 - accuracy: 0.8180 - val_loss: 0.4415 - val_accuracy: 0.8380 - 69ms/epoch - 4ms/step
# Epoch 64/100
# 16/16 - 0s - loss: 0.4427 - accuracy: 0.8260 - val_loss: 0.4355 - val_accuracy: 0.8440 - 58ms/epoch - 4ms/step
# Epoch 65/100
# 16/16 - 0s - loss: 0.4414 - accuracy: 0.8200 - val_loss: 0.4355 - val_accuracy: 0.8120 - 78ms/epoch - 5ms/step
# Epoch 66/100
# 16/16 - 0s - loss: 0.4378 - accuracy: 0.8260 - val_loss: 0.4310 - val_accuracy: 0.8400 - 60ms/epoch - 4ms/step
# Epoch 67/100
# 16/16 - 0s - loss: 0.4353 - accuracy: 0.8200 - val_loss: 0.4298 - val_accuracy: 0.8260 - 78ms/epoch - 5ms/step
# Epoch 68/100
# 16/16 - 0s - loss: 0.4341 - accuracy: 0.8280 - val_loss: 0.4279 - val_accuracy: 0.8340 - 60ms/epoch - 4ms/step
# Epoch 69/100
# 16/16 - 0s - loss: 0.4330 - accuracy: 0.8180 - val_loss: 0.4251 - val_accuracy: 0.8420 - 72ms/epoch - 5ms/step
# Epoch 70/100
# 16/16 - 0s - loss: 0.4297 - accuracy: 0.8280 - val_loss: 0.4250 - val_accuracy: 0.8360 - 65ms/epoch - 4ms/step
# Epoch 71/100
# 16/16 - 0s - loss: 0.4277 - accuracy: 0.8240 - val_loss: 0.4230 - val_accuracy: 0.8380 - 70ms/epoch - 4ms/step
# Epoch 72/100
# 16/16 - 0s - loss: 0.4280 - accuracy: 0.8220 - val_loss: 0.4198 - val_accuracy: 0.8340 - 78ms/epoch - 5ms/step
# Epoch 73/100
# 16/16 - 0s - loss: 0.4256 - accuracy: 0.8240 - val_loss: 0.4169 - val_accuracy: 0.8340 - 69ms/epoch - 4ms/step
# Epoch 74/100
# 16/16 - 0s - loss: 0.4227 - accuracy: 0.8280 - val_loss: 0.4161 - val_accuracy: 0.8300 - 68ms/epoch - 4ms/step
# Epoch 75/100
# 16/16 - 0s - loss: 0.4217 - accuracy: 0.8220 - val_loss: 0.4166 - val_accuracy: 0.8400 - 60ms/epoch - 4ms/step
# Epoch 76/100
# 16/16 - 0s - loss: 0.4190 - accuracy: 0.8220 - val_loss: 0.4126 - val_accuracy: 0.8380 - 70ms/epoch - 4ms/step
# Epoch 77/100
# 16/16 - 0s - loss: 0.4186 - accuracy: 0.8280 - val_loss: 0.4118 - val_accuracy: 0.8380 - 60ms/epoch - 4ms/step
# Epoch 78/100
# 16/16 - 0s - loss: 0.4186 - accuracy: 0.8300 - val_loss: 0.4126 - val_accuracy: 0.8380 - 70ms/epoch - 4ms/step
# Epoch 79/100
# 16/16 - 0s - loss: 0.4155 - accuracy: 0.8240 - val_loss: 0.4084 - val_accuracy: 0.8400 - 60ms/epoch - 4ms/step
# Epoch 80/100
# 16/16 - 0s - loss: 0.4165 - accuracy: 0.8320 - val_loss: 0.4074 - val_accuracy: 0.8360 - 60ms/epoch - 4ms/step
# Epoch 81/100
# 16/16 - 0s - loss: 0.4169 - accuracy: 0.8200 - val_loss: 0.4091 - val_accuracy: 0.8380 - 70ms/epoch - 4ms/step
# Epoch 82/100
# 16/16 - 0s - loss: 0.4176 - accuracy: 0.8160 - val_loss: 0.4044 - val_accuracy: 0.8440 - 70ms/epoch - 4ms/step
# Epoch 83/100
# 16/16 - 0s - loss: 0.4197 - accuracy: 0.8220 - val_loss: 0.4028 - val_accuracy: 0.8360 - 69ms/epoch - 4ms/step
# Epoch 84/100
# 16/16 - 0s - loss: 0.4130 - accuracy: 0.8340 - val_loss: 0.4050 - val_accuracy: 0.8340 - 59ms/epoch - 4ms/step
# Epoch 85/100
# 16/16 - 0s - loss: 0.4124 - accuracy: 0.8320 - val_loss: 0.4020 - val_accuracy: 0.8320 - 70ms/epoch - 4ms/step
# Epoch 86/100
# 16/16 - 0s - loss: 0.4126 - accuracy: 0.8120 - val_loss: 0.4021 - val_accuracy: 0.8420 - 71ms/epoch - 4ms/step
# Epoch 87/100
# 16/16 - 0s - loss: 0.4092 - accuracy: 0.8260 - val_loss: 0.3991 - val_accuracy: 0.8320 - 70ms/epoch - 4ms/step
# Epoch 88/100
# 16/16 - 0s - loss: 0.4076 - accuracy: 0.8240 - val_loss: 0.3989 - val_accuracy: 0.8460 - 70ms/epoch - 4ms/step
# Epoch 89/100
# 16/16 - 0s - loss: 0.4049 - accuracy: 0.8260 - val_loss: 0.3974 - val_accuracy: 0.8440 - 81ms/epoch - 5ms/step
# Epoch 90/100
# 16/16 - 0s - loss: 0.4055 - accuracy: 0.8180 - val_loss: 0.3988 - val_accuracy: 0.8340 - 90ms/epoch - 6ms/step
# Epoch 91/100
# 16/16 - 0s - loss: 0.4049 - accuracy: 0.8280 - val_loss: 0.3959 - val_accuracy: 0.8180 - 69ms/epoch - 4ms/step
# Epoch 92/100
# 16/16 - 0s - loss: 0.4025 - accuracy: 0.8320 - val_loss: 0.3959 - val_accuracy: 0.8400 - 70ms/epoch - 4ms/step
# Epoch 93/100
# 16/16 - 0s - loss: 0.4044 - accuracy: 0.8240 - val_loss: 0.3954 - val_accuracy: 0.8380 - 70ms/epoch - 4ms/step
# Epoch 94/100
# 16/16 - 0s - loss: 0.4050 - accuracy: 0.8300 - val_loss: 0.3920 - val_accuracy: 0.8440 - 70ms/epoch - 4ms/step
# Epoch 95/100
# 16/16 - 0s - loss: 0.4026 - accuracy: 0.8300 - val_loss: 0.3962 - val_accuracy: 0.8340 - 76ms/epoch - 5ms/step
# Epoch 96/100
# 16/16 - 0s - loss: 0.4029 - accuracy: 0.8340 - val_loss: 0.3916 - val_accuracy: 0.8220 - 69ms/epoch - 4ms/step
# Epoch 97/100
# 16/16 - 0s - loss: 0.3998 - accuracy: 0.8220 - val_loss: 0.3913 - val_accuracy: 0.8440 - 76ms/epoch - 5ms/step
# Epoch 98/100
# 16/16 - 0s - loss: 0.4053 - accuracy: 0.8320 - val_loss: 0.3893 - val_accuracy: 0.8380 - 74ms/epoch - 5ms/step
# Epoch 99/100
# 16/16 - 0s - loss: 0.4006 - accuracy: 0.8300 - val_loss: 0.3896 - val_accuracy: 0.8420 - 76ms/epoch - 5ms/step
# Epoch 100/100
# 16/16 - 0s - loss: 0.4020 - accuracy: 0.8200 - val_loss: 0.3883 - val_accuracy: 0.8440 - 74ms/epoch - 5ms/step

# %% [markdown]
# # Evaluate the model

# %%
_,train_acc=model.evaluate(trainX,trainy,verbose=1)
_,test_acc=model.evaluate(testX,testy,verbose=1)
print('Train Accuracy:\t', train_acc)
print()
print('Test Accuracy:\t',test_acc)
# Out:
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3943 - accuracy: 0.8300
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3883 - accuracy: 0.8440
# Train Accuracy:	 0.8299999833106995
#
# Test Accuracy:	 0.843999981880188

# %% [markdown]
# # plot the result

# %%
pyplot.plot(history.history['accuracy'],label='train')
pyplot.plot(history.history['val_accuracy'],label='test')
pyplot.legend()
pyplot.show()

# %%
pyplot.plot(history.history['loss'],label='train')
pyplot.plot(history.history['val_loss'],label='test')
pyplot.legend()
pyplot.show()

# %%
# !pip install pandoc
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandoc
#   Downloading pandoc-2.3.tar.gz (33 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting plumbum (from pandoc)
#   Obtaining dependency information for plumbum from https://files.pythonhosted.org/packages/6f/e8/a9a580d1d67825d8bdc16f3993ea58c4066769d5f8ba34caaa69a5344b39/plumbum-1.8.2-py3-none-any.whl.metadata
#   Downloading plumbum-1.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: ply in c:\programdata\anaconda3\lib\site-packages (from pandoc) (3.11)
# Requirement already satisfied: pywin32 in c:\programdata\anaconda3\lib\site-packages (from plumbum->pandoc) (305.1)
# Downloading plumbum-1.8.2-py3-none-any.whl (127 kB)
#    ---------------------------------------- 0.0/127.0 kB ? eta -:--:--
#    ------------ --------------------------- 41.0/127.0 kB ? eta -:--:--
#    ------------ --------------------------- 41.0/127.0 kB ? eta -:--:--
#    ------------ --------------------------- 41.0/127.0 kB ? eta -:--:--
#    ------------ --------------------------- 41.0/127.0 kB ? eta -:--:--
#    ------------ --------------------------- 41.0/127.0 kB ? eta -:--:--
#    ------------------ ------------------- 61.4/127.0 kB 192.5 kB/s eta 0:00:01
#    --------------------- ---------------- 71.7/127.0 kB 217.9 kB/s eta 0:00:01
#    --------------------------- ---------- 92.2/127.0 kB 249.0 kB/s eta 0:00:01
#    --------------------------- ---------- 92.2/127.0 kB 249.0 kB/s eta 0:00:01
#    ----------------------------------- - 122.9/127.0 kB 276.8 kB/s eta 0:00:01
#    ----------------------------------- - 122.9/127.0 kB 276.8 kB/s eta 0:00:01
#    ------------------------------------- 127.0/127.0 kB 213.5 kB/s eta 0:00:00
# Building wheels for collected packages: pandoc
#   Building wheel for pandoc (setup.py): started
#   Building wheel for pandoc (setup.py): finished with status 'done'
#   Created wheel for pandoc: filename=pandoc-2.3-py3-none-any.whl size=33290 sha256=a44bbcc5e27d915e4b8f8c20bd8adb92bc01bbf2b2c16f5138f889b9b1401708
#   Stored in directory: c:\users\shabaz\appdata\local\pip\cache\wheels\1c\a9\c4\6254542c4e8202d52fcd69798d2507aaad1f2a4bb60f2f0fea
# Successfully built pandoc
# Installing collected packages: plumbum, pandoc
# Successfully installed pandoc-2.3 plumbum-1.8.2
